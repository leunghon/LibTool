# %%
pip install unidecode
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 kB 1.6 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from unidecode import unidecode
df1 = pd.read_excel('dataset2.xlsx')
df2 = df1
df2.fillna('', inplace=True)
# df2['authorEnglish2']=unidecode(df2['authorEnglish'])+"/"+df2['authorEnglish']
names = []
for d in df2['authorEnglish']:
    if(unidecode(d) == d):
        d2 = d.replace("-"," ")
        if(d != d2):
            names.append(d2+"/"+d)
        else:
            names.append(d)
    else:
        d2 = unidecode(d)
        d3 = d2.replace("-"," ")
        if(d3!=d2):
            names.append(d3+"/"+d2+"/"+d)
        else:
            names.append(d3+"/"+d)
names
df2['authorEnglish2']=names

# %%
# Lets use what has already been done
df1
# Out:
#       Unnamed: 0    GENRE authorKorean   authorEnglish
# 0              0  Fiction          강경애   Kang Kyung-ae  \
# 1              1  Fiction          강경애  Kang Kyŏng-ae
# 2              2  Fiction          강경애   Kang Kyung-ae
# 3              3  Fiction          강경애  Kang Kyeong-ae
# 4              4  Fiction          강경애   Kang kyong-ae
# ...          ...      ...          ...             ...
# 2441        2441    Misc.          이시우      Lee Si-Woo
# 2442        2442    Misc.          장인명   Chang Inmyŏng
# 2443        2443    Misc.
# 2444        2444    Misc.
# 2445        2445    Misc.
#
#                          workTitle                    translator
# 0                                               Sora Kim-Russell  \
# 1                                                   Samuel Perry
# 2                                               Sora Kim-Russell
# 3                                                      Anton Hur
# ...

# %%
df1 = pd.read_csv('dataClean.csv')
print("before duplicates:-",df1.shape[0])
df3 = df1[df1.duplicated(["GENRE","sourceTitle","workTitle","publisher","yearCreated","translator", "authorKorean", "authorEnglish"],keep=False)]
print("No. of duplicates:-",df3.shape[0])
df3.to_csv('ptDuplicates.csv')
df4 = df1.drop_duplicates(subset=["GENRE","sourceTitle","workTitle","publisher","yearCreated","translator", "authorKorean", "authorEnglish"], keep='last')
print("after getting rid of duplicates:-",df4.shape[0])
df4.to_csv('dataWithOutDups.csv')
df5 = df1[df1.duplicated(["GENRE","sourceTitle","publisher","yearCreated","translator", "authorKorean", "authorEnglish"],keep=False)]
print("No. of duplicates without workTitle included:-",df5.shape[0])
df5.to_csv('DuplicatesWoWorktitle.csv')
# Out:
# before duplicates:- 2446
# No. of duplicates:- 14
# after getting rid of duplicates:- 2439
# No. of duplicates without workTitle included:- 322

# %%
# df2['yearCreated'] = pd.to_numeric(df2['yearCreated'],errors='coerce')
df4['yearCreated'] = pd.to_numeric(df4['yearCreated'],errors='coerce')
# Out:
# /var/folders/tb/49z896tj7l7227p_6d7yg57r0000gn/T/ipykernel_5878/1697037054.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['yearCreated'] = pd.to_numeric(df4['yearCreated'],errors='coerce')

# %%
df2.to_csv('dataClean.csv')
df4.to_csv('dataClean2.csv')

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df2
#
# NameError: name 'df2' is not defined
